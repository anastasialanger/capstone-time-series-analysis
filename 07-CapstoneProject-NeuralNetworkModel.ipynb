# %% [markdown]
# ## 7. Neural Network model

# %% [markdown]
# <li> Build a Neural Network model with 2 hidden layers. </li> <li> Train the model and tune the number of neurons in the layers for a one time-series from each cluster. </li> <li> Using found parameters, compute the forecast for a different time-series from the same cluster. </li>

# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# Out:
# /Users/anastasiagolubkova/anaconda3/envs/exts-ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/anastasiagolubkova/anaconda3/envs/exts-ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/anastasiagolubkova/anaconda3/envs/exts-ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/anastasiagolubkova/anaconda3/envs/exts-ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/anastasiagolubkova/anaconda3/envs/exts-ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/anastasiagolubkova/anaconda3/envs/exts-ml/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df = pd.read_pickle('demand_data_for_modelling')
df.head(5)
# Out:
#    meter_id                date  demand  hours  normalized_demand  demand-24h  \
# 0         1 2005-01-01 00:00:00  3304.0    0.0           0.330996         NaN
# 1         1 2005-01-01 01:00:00  3178.0    1.0           0.318373         NaN
# 2         1 2005-01-01 02:00:00  2981.0    2.0           0.298638         NaN
# 3         1 2005-01-01 03:00:00  2944.0    3.0           0.294931         NaN
# 4         1 2005-01-01 04:00:00  2934.0    4.0           0.293929         NaN
#
#    normalized_demand-24h
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
temperature = pd.read_pickle('temperature_for_modelling')
temperature.head(5)
# Out:
#             full_date  hourly_mean  normalized_temp
# 0 2005-01-01 00:00:00    44.535714         0.390571
# 1 2005-01-01 01:00:00    44.428571         0.389273
# 2 2005-01-01 02:00:00    43.535714         0.378460
# 3 2005-01-01 03:00:00    43.750000         0.381055
# 4 2005-01-01 04:00:00    43.321429         0.375865

# %%
humidity = pd.read_pickle('humidity_for_modelling')
humidity.head(5)
# Out:
#             full_date  hourly_mean  normalized_humidity
# 0 2005-01-01 00:00:00    87.535714             0.879677
# 1 2005-01-01 01:00:00    86.678571             0.869473
# 2 2005-01-01 02:00:00    86.964286             0.872874
# 3 2005-01-01 03:00:00    87.214286             0.875850
# 4 2005-01-01 04:00:00    87.357143             0.877551

# %% [markdown]
# Functions for modelling
# --

# %% [markdown]
# Split the data into train, validation, and test sets:

# %%
def train_val_test_split(df, test_fraction, cols):
    train_fraction = 1-test_fraction
    val_fraction = train_fraction + test_fraction/2
    dates = df.groupby(df.date.dt.date).count().date 
    split_train = (int)(len(dates)*train_fraction)
    split_val = (int)(len(dates)*val_fraction)
    end_train_date = pd.to_datetime(dates.index[split_train])
    end_val_date = pd.to_datetime(dates.index[split_val])
    
    X_tr = df[df.date < end_train_date][cols].values
    y_tr = df[df.date < end_train_date]['normalized_demand'].values
                        
    X_val = df[(df.date >= end_train_date) & (df.date < end_val_date)][cols].values
    y_val = df[(df.date >= end_train_date) & (df.date < end_val_date)]['normalized_demand'].values
    
    X_te = df[df.date >= end_val_date][cols].values
    y_te = df[df.date >= end_val_date]['normalized_demand'].values
    
    print('Train set')
    print('---------')
    print('Features: {} Target: {}\n'.format(X_tr.shape,y_tr.shape))
    
    print('Validation set')
    print('---------')
    print('Features: {} Target: {}\n'.format(X_val.shape,y_val.shape))

    print('Test set')
    print('--------')    
    print('Features: {} Target: {}'.format(X_te.shape,y_te.shape))
    
    return (X_tr,X_val,X_te,y_tr,y_val,y_te)

# %% [markdown]
# Build samples for a supervised model:

# %%
def split_into_samples(X_features, y_target, event_length_features, event_length_target):
    
    # Function to split a time-series into samples: 
    # example [X1,X2,X3] features -> [y4,y5,y6] target
    
    X = []
    y = []
    
    for i in np.arange(len(X_features)):
        X_end_ind = i + event_length_features
        y_end_ind = X_end_ind + event_length_target-1
        
        if (y_end_ind <= len(X_features)):
            features = X_features[i:X_end_ind,:]
            target = y_target[X_end_ind-1:y_end_ind]
        
        X.append(features)
        y.append(target)

    print('Features samples: ', np.array(X).shape)   
    print('Target samples: ', np.array(y).shape)
        
    return np.array(X), np.array(y)

# %% [markdown]
# Build a Neural Network model:

# %%
def neural_network_model(n,epochs,batch_size,X_tr_samples,X_val_samples,y_tr_samples,y_val_samples):
    
    # Function to build and train a NN model with 2 hidden layers
    # n is a list with a number of neurons in each hidden layer
    
    # Define a network
    model = keras.Sequential()
    model.add(keras.layers.Dense(units=n[0], activation='relu', input_dim=(X_tr_samples.shape[1]*X_tr_samples.shape[2])))
    model.add(keras.layers.Dense(units=n[1], activation='relu'))
    model.add(keras.layers.Dense(units=y_tr_samples.shape[1]))
    print('Network configuration')
    model.summary()
    
    model.compile(optimizer=keras.optimizers.Adam(), loss='mse')
    
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    
    # Train a network
    history = model.fit(
        # Flatten the input 
        X_tr_samples.reshape(X_tr_samples.shape[0], X_tr_samples.shape[1]*X_tr_samples.shape[2]), 
        y_tr_samples, 
        epochs=epochs, 
        batch_size=batch_size, 
        verbose=1,
        shuffle=True,
        validation_data = \
        (X_val_samples.reshape(X_val_samples.shape[0], X_val_samples.shape[1]*X_val_samples.shape[2]), y_val_samples), 
        callbacks=[early_stopping]
    )
    
    # Plot the results
    plt.plot(history.history['val_loss'][0:], label='validation')
    plt.plot(history.history['loss'][0:], label='training') 
    plt.legend()
    plt.show()
    
    return model

# %% [markdown]
# Compute MAE:

# %%
def MAE(y,y_pred):    
    return(np.mean(np.abs(y-y_pred)))

# %% [markdown]
# Plot the results:

# %%
def plot_predictions(X_tr,X_val,X_te,y_tr,y_val,y_te,y_pred_tr,y_pred_val,y_pred_te):
    
    font = {'fontname':'Arial', 'size':'14'}
    font_title = {'fontname':'Arial', 'size':'16'}

    plt.figure(figsize=(9,6))

    # True values
    plt.plot(X_tr[:,0],y_tr,label='train set',color='black')
    plt.plot(X_val[:,0],y_val,label='validation set',color='orange') 
    plt.plot(X_te[:,0],y_te,label='test set',color='grey')    

    # Predictions
    plt.plot(X_tr[:,0],y_pred_tr[:,0],label='predictions train',color='blue')
    plt.plot(X_val[:,0],y_pred_val[:,0],label='predictions validation',color='green')
    plt.plot(X_te[:,0],y_pred_te[:,0],label='predictions test',color='red')     

    plt.xlabel('Date',**font)
    plt.ylabel('Electricity demand',**font)

    plt.legend()
    plt.show()

# %% [markdown]
# Save the results:

# %%
def save_result(meter_id,X_tr,X_val,X_te,y_pred_tr,y_pred_val,y_pred_te):
    
    df1 = pd.DataFrame({"meter_id": [meter_id]*X_tr.shape[0], "date": X_tr[:,0], \
                        "type": ['training']*X_tr.shape[0], "pred_value": y_pred_tr})
    
    df2 = pd.DataFrame({"meter_id": [meter_id]*X_val.shape[0], "date": X_val[:,0], \
                        "type": ['validation']*X_val.shape[0], "pred_value": y_pred_val})
    
    df3 = pd.DataFrame({"meter_id": [meter_id]*X_te.shape[0], "date": X_te[:,0], \
                        "type": ['test']*X_te.shape[0], "pred_value": y_pred_te})
    
    result = pd.concat([df1,df2,df3], ignore_index=True)
    return result

# %% [markdown]
# __Cluster 1__

# %% [markdown]
# Tune a Neural Network model for a one time-series, meter 422, from the cluster 1.

# %%
meter_422 = df[df['meter_id']==422]
temperature_422 = temperature[temperature.full_date.isin(meter_422.date)]
humidity_422 = humidity[humidity.full_date.isin(meter_422.date)]
meter_422 = meter_422[meter_422.date.isin(temperature_422.full_date)]
meter_422 = meter_422[meter_422.date.isin(humidity_422.full_date)]
meter_422 = meter_422.reset_index()
meter_422['normalized_temp'] = temperature_422.normalized_temp
meter_422['normalized_humid'] = humidity_422.normalized_humidity
meter_422.head(5)
# Out:
#      index  meter_id                date   demand  hours  normalized_demand  \
# 0  8347632       422 2005-01-01 00:00:00  12258.0    0.0           0.440665
# 1  8347633       422 2005-01-01 01:00:00   8016.0    1.0           0.240268
# 2  8347634       422 2005-01-01 02:00:00   7813.0    2.0           0.230678
# 3  8347635       422 2005-01-01 03:00:00   7527.0    3.0           0.217167
# 4  8347636       422 2005-01-01 04:00:00   7529.0    4.0           0.217262
#
#    demand-24h  normalized_demand-24h  normalized_temp  normalized_humid
# 0         NaN                    NaN         0.390571          0.879677
# 1         NaN                    NaN         0.389273          0.869473
# 2         NaN                    NaN         0.378460          0.872874
# 3         NaN                    NaN         0.381055          0.875850
# 4         NaN                    NaN         0.375865          0.877551

# %%
meter_422.dropna(inplace=True)

# %% [markdown]
# Split the data into training, validation, and test sets:

# %%
X_tr_422,X_val_422,X_te_422,y_tr_422,y_val_422,y_te_422 = \
train_val_test_split(meter_422, 0.2, ['date','normalized_demand-24h','normalized_temp','normalized_humid'])
# Out:
# Train set
# ---------
# Features: (49050, 4) Target: (49050,)
#
# Validation set
# ---------
# Features: (6119, 4) Target: (6119,)
#
# Test set
# --------
# Features: (6144, 4) Target: (6144,)

# %% [markdown]
# Define the samples for training, validation, and test. Modelled event length is 24 hours:

# %%
X_tr_samples_422, y_tr_samples_422 = split_into_samples(X_tr_422[:,1:],y_tr_422,24,24)
# Out:
# Features samples:  (49050, 24, 3)
# Target samples:  (49050, 24)

# %%
X_val_samples_422, y_val_samples_422 = split_into_samples(X_val_422[:,1:],y_val_422,24,24)
# Out:
# Features samples:  (6119, 24, 3)
# Target samples:  (6119, 24)

# %%
X_te_samples_422, y_te_samples_422 = split_into_samples(X_te_422[:,1:],y_te_422,24,24)
# Out:
# Features samples:  (6144, 24, 3)
# Target samples:  (6144, 24)

# %% [markdown]
# Build a model with 2 hidden layers and try various number of neurons:

# %%
# Try various number of neurons per each hidden layer
n_config = [5,5],[10,5],[20,10]

search_result_422 = []
epochs = 2000
batch_size = None

for i in np.arange(len(n_config)):
    print('Tuning neural network for meter 422')
    print('-----------------')
    print('CONFIGURATION SET ' + str(n_config[i]))
    print('-----------------')
    
    model_422 = \
    neural_network_model(n_config[i],epochs,batch_size,X_tr_samples_422,X_val_samples_422,y_tr_samples_422,y_val_samples_422)
    
    # Compute the prediction for this model
    y_pred = \
    model_422.predict(X_te_samples_422.reshape(X_te_samples_422.shape[0], X_te_samples_422.shape[1]*X_te_samples_422.shape[2]), verbose=1)
    
    # Save prediction errors to the dataframe
    result = {'Config': str(n_config[i]), 'MAE_te': (MAE(y_te_samples_422[:,0], y_pred[:,0]))}
    search_result_422.append(result)

search_result_422 = pd.DataFrame(search_result_422)
# Out:
# -----------------
# CONFIGURATION SET [5, 5]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 365
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                144
# =================================================================
# Total params: 539
# Trainable params: 539
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 7s 137us/step - loss: 0.0198 - val_loss: 0.0127
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 92us/step - loss: 0.0135 - val_loss: 0.0124
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 97us/step - loss: 0.0133 - val_loss: 0.0122
# Epoch 4/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0133 - val_loss: 0.0123
# Epoch 5/2000
# 49050/49050 [==============================] - 9s 175us/step - loss: 0.0133 - val_loss: 0.0122
# Epoch 6/2000
# 49050/49050 [==============================] - 10s 207us/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 7/2000
# 49050/49050 [==============================] - 9s 193us/step - loss: 0.0132 - val_loss: 0.0122
# Epoch 8/2000
# 49050/49050 [==============================] - 7s 152us/step - loss: 0.0132 - val_loss: 0.0122
# Epoch 9/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0132 - val_loss: 0.0124
# Epoch 10/2000
# 49050/49050 [==============================] - 6s 125us/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 99us/step - loss: 0.0132 - val_loss: 0.0122
# Epoch 12/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 13/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 14/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 15/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 16/2000
# 49050/49050 [==============================] - 9s 188us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 17/2000
# 49050/49050 [==============================] - 7s 135us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 18/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0131 - val_loss: 0.0123
# Epoch 19/2000
# 49050/49050 [==============================] - 11s 230us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 20/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0131 - val_loss: 0.0123
# Epoch 21/2000
# 49050/49050 [==============================] - 7s 145us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 22/2000
# 49050/49050 [==============================] - 9s 178us/step - loss: 0.0131 - val_loss: 0.0124
# Epoch 23/2000
# 49050/49050 [==============================] - 5s 100us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 24/2000
# 49050/49050 [==============================] - 5s 100us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 25/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 26/2000
# 49050/49050 [==============================] - 7s 137us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 27/2000
# 49050/49050 [==============================] - 5s 92us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 28/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 29/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 30/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0131 - val_loss: 0.0122
# Epoch 31/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 32/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0131 - val_loss: 0.0120
# Epoch 33/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 34/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 35/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 36/2000
# 49050/49050 [==============================] - 5s 92us/step - loss: 0.0131 - val_loss: 0.0123
# Epoch 37/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0131 - val_loss: 0.0120
# Epoch 38/2000
# 49050/49050 [==============================] - 4s 91us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 39/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 40/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0131 - val_loss: 0.0120
# Epoch 41/2000
# 49050/49050 [==============================] - 7s 138us/step - loss: 0.0131 - val_loss: 0.0121
# Epoch 42/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0131 - val_loss: 0.0121
# 6144/6144 [==============================] - 0s 73us/step
# -----------------
# CONFIGURATION SET [10, 5]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                730
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                144
# =================================================================
# Total params: 929
# Trainable params: 929
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0222 - val_loss: 0.0131
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 92us/step - loss: 0.0134 - val_loss: 0.0121
# Epoch 3/2000
# 49050/49050 [==============================] - 7s 143us/step - loss: 0.0132 - val_loss: 0.0120
# Epoch 4/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0131 - val_loss: 0.0120
# Epoch 5/2000
# 49050/49050 [==============================] - 7s 137us/step - loss: 0.0116 - val_loss: 0.0107
# Epoch 6/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 7/2000
# 49050/49050 [==============================] - 8s 164us/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 8/2000
# 49050/49050 [==============================] - 7s 140us/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 9/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 10/2000
# 49050/49050 [==============================] - 6s 128us/step - loss: 0.0084 - val_loss: 0.0092
# Epoch 11/2000
# 49050/49050 [==============================] - 9s 184us/step - loss: 0.0075 - val_loss: 0.0086
# Epoch 12/2000
# 49050/49050 [==============================] - 9s 177us/step - loss: 0.0074 - val_loss: 0.0087
# Epoch 13/2000
# 49050/49050 [==============================] - 7s 143us/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 15/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0068 - val_loss: 0.0080
# Epoch 16/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0064 - val_loss: 0.0078
# Epoch 17/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0060 - val_loss: 0.0075
# Epoch 18/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0058 - val_loss: 0.0073
# Epoch 19/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0056 - val_loss: 0.0070
# Epoch 20/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 21/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0055 - val_loss: 0.0069
# Epoch 22/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0054 - val_loss: 0.0069
# Epoch 23/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0054 - val_loss: 0.0070
# Epoch 24/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0053 - val_loss: 0.0069
# Epoch 25/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0053 - val_loss: 0.0067
# Epoch 26/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 27/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 28/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 29/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 30/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 31/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 32/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 33/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 34/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0050 - val_loss: 0.0065
# Epoch 35/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 36/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 37/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0049 - val_loss: 0.0064
# Epoch 38/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0049 - val_loss: 0.0067
# Epoch 39/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0049 - val_loss: 0.0064
# Epoch 40/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 41/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 42/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 43/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0049 - val_loss: 0.0064
# Epoch 44/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 45/2000
# 49050/49050 [==============================] - 4s 91us/step - loss: 0.0049 - val_loss: 0.0066
# Epoch 46/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0049 - val_loss: 0.0064
# Epoch 47/2000
# 49050/49050 [==============================] - 4s 91us/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 48/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0048 - val_loss: 0.0063
# Epoch 49/2000
# 49050/49050 [==============================] - 4s 91us/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 50/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 51/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0048 - val_loss: 0.0065
# Epoch 52/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0048 - val_loss: 0.0062
# Epoch 53/2000
# 49050/49050 [==============================] - 4s 90us/step - loss: 0.0048 - val_loss: 0.0061
# Epoch 54/2000
# 49050/49050 [==============================] - 4s 91us/step - loss: 0.0048 - val_loss: 0.0063
# 6144/6144 [==============================] - 0s 33us/step
# -----------------
# CONFIGURATION SET [20, 10]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 20)                1460
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                264
# =================================================================
# Total params: 1,934
# Trainable params: 1,934
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 5s 103us/step - loss: 0.0229 - val_loss: 0.0109
# Epoch 2/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 3/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0068 - val_loss: 0.0080
# Epoch 4/2000
# 49050/49050 [==============================] - 4s 84us/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 5/2000
# 49050/49050 [==============================] - 4s 84us/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 6/2000
# 49050/49050 [==============================] - 4s 84us/step - loss: 0.0053 - val_loss: 0.0062
# Epoch 7/2000
# 49050/49050 [==============================] - 4s 84us/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 8/2000
# 49050/49050 [==============================] - 4s 84us/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 9/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 10/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0046 - val_loss: 0.0060
# Epoch 11/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0045 - val_loss: 0.0059
# Epoch 12/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0044 - val_loss: 0.0056
# Epoch 13/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 14/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 15/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 16/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 17/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0043 - val_loss: 0.0054
# Epoch 18/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0043 - val_loss: 0.0054
# Epoch 19/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 20/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 21/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 22/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0042 - val_loss: 0.0054
# Epoch 23/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 24/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 25/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 26/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 27/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 28/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 29/2000
# 49050/49050 [==============================] - 5s 92us/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 30/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 31/2000
# 49050/49050 [==============================] - 4s 85us/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 32/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 33/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0041 - val_loss: 0.0051
# Epoch 34/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 35/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 36/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 37/2000
# 49050/49050 [==============================] - 4s 91us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 38/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 39/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 40/2000
# 49050/49050 [==============================] - 4s 86us/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 41/2000
# 49050/49050 [==============================] - 5s 96us/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 42/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 43/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 44/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 45/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 46/2000
# 49050/49050 [==============================] - 4s 88us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 47/2000
# 49050/49050 [==============================] - 4s 89us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 48/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 49/2000
# 49050/49050 [==============================] - 4s 87us/step - loss: 0.0040 - val_loss: 0.0052
# 6144/6144 [==============================] - 0s 36us/step

# %%
search_result_422.sort_values(by = 'MAE_te', ascending=True)
# Out:
#      Config    MAE_te
# 2  [20, 10]  0.040718
# 1   [10, 5]  0.046403
# 0    [5, 5]  0.093880

# %% [markdown]
# The configuration with 20 neurons in the first layer and 10 neurons in the second layer will be used to compute the forecast for meter 481:

# %%
meter_481 = df[df['meter_id']==481]
temperature_481 = temperature[temperature.full_date.isin(meter_481.date)].reset_index()
humidity_481 = humidity[humidity.full_date.isin(meter_481.date)].reset_index()
meter_481 = meter_481[meter_481.date.isin(temperature_481.full_date)]
meter_481 = meter_481[meter_481.date.isin(humidity_481.full_date)]
meter_481 = meter_481.reset_index()
meter_481['normalized_temp'] = temperature_481.normalized_temp
meter_481['normalized_humid'] = humidity_481.normalized_humidity
meter_481.head()
# Out:
#      index  meter_id                date  demand  hours  normalized_demand  \
# 0  9432360       481 2009-04-16 00:00:00     0.0    0.0           0.000000
# 1  9432361       481 2009-04-16 01:00:00     0.0    1.0           0.000000
# 2  9432362       481 2009-04-16 02:00:00     8.0    2.0           0.000563
# 3  9432363       481 2009-04-16 03:00:00     7.0    3.0           0.000492
# 4  9432364       481 2009-04-16 04:00:00     8.0    4.0           0.000563
#
#    demand-24h  normalized_demand-24h  normalized_temp  normalized_humid
# 0         NaN                    NaN         0.424740          0.740221
# 1         NaN                    NaN         0.410900          0.750850
# 2         NaN                    NaN         0.397491          0.763605
# 3         NaN                    NaN         0.387543          0.764881
# 4         NaN                    NaN         0.380623          0.773384

# %%
meter_481.dropna(inplace=True)

# %% [markdown]
# Split the data into training, validation, and test sets and generate the samples:

# %%
X_tr_481,X_val_481,X_te_481,y_tr_481,y_val_481,y_te_481 = \
train_val_test_split(meter_481, 0.2, ['date','normalized_demand-24h','normalized_temp','normalized_humid'])
# Out:
# Train set
# ---------
# Features: (18982, 4) Target: (18982,)
#
# Validation set
# ---------
# Features: (2376, 4) Target: (2376,)
#
# Test set
# --------
# Features: (2376, 4) Target: (2376,)

# %%
X_tr_samples_481, y_tr_samples_481 = split_into_samples(X_tr_481[:,1:],y_tr_481,24,24)
# Out:
# Features samples:  (18982, 24, 3)
# Target samples:  (18982, 24)

# %%
X_val_samples_481, y_val_samples_481 = split_into_samples(X_val_481[:,1:],y_val_481,24,24)
# Out:
# Features samples:  (2376, 24, 3)
# Target samples:  (2376, 24)

# %%
X_te_samples_481, y_te_samples_481 = split_into_samples(X_te_481[:,1:],y_te_481,24,24)
# Out:
# Features samples:  (2376, 24, 3)
# Target samples:  (2376, 24)

# %% [markdown]
# Train the network:

# %%
model_481 = \
    neural_network_model([20,10],2000,None,X_tr_samples_481,X_val_samples_481,y_tr_samples_481,y_val_samples_481)
# Out:
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 20)                1460
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_14 (Dense)             (None, 24)                264
# =================================================================
# Total params: 1,934
# Trainable params: 1,934
# Non-trainable params: 0
# _________________________________________________________________
# Train on 18982 samples, validate on 2376 samples
# Epoch 1/2000
# 18982/18982 [==============================] - 3s 159us/step - loss: 0.0408 - val_loss: 0.0122
# Epoch 2/2000
# 18982/18982 [==============================] - 2s 93us/step - loss: 0.0096 - val_loss: 0.0072
# Epoch 3/2000
# 18982/18982 [==============================] - 2s 118us/step - loss: 0.0084 - val_loss: 0.0071
# Epoch 4/2000
# 18982/18982 [==============================] - 2s 109us/step - loss: 0.0078 - val_loss: 0.0063
# Epoch 5/2000
# 18982/18982 [==============================] - 2s 93us/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 6/2000
# 18982/18982 [==============================] - 2s 94us/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 7/2000
# 18982/18982 [==============================] - 2s 100us/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 8/2000
# 18982/18982 [==============================] - 2s 110us/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 9/2000
# 18982/18982 [==============================] - 3s 147us/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 10/2000
# 18982/18982 [==============================] - 4s 195us/step - loss: 0.0056 - val_loss: 0.0068
# Epoch 11/2000
# 18982/18982 [==============================] - 3s 184us/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 12/2000
# 18982/18982 [==============================] - 2s 96us/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 13/2000
# 18982/18982 [==============================] - 2s 91us/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 14/2000
# 18982/18982 [==============================] - 2s 90us/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 15/2000
# 18982/18982 [==============================] - 2s 91us/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 16/2000
# 18982/18982 [==============================] - 2s 103us/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 17/2000
# 18982/18982 [==============================] - 2s 89us/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 18/2000
# 18982/18982 [==============================] - 2s 92us/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 19/2000
# 18982/18982 [==============================] - 2s 95us/step - loss: 0.0051 - val_loss: 0.0059
# Epoch 20/2000
# 18982/18982 [==============================] - 2s 103us/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 21/2000
# 18982/18982 [==============================] - 2s 103us/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 22/2000
# 18982/18982 [==============================] - 2s 97us/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 23/2000
# 18982/18982 [==============================] - 2s 107us/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 24/2000
# 18982/18982 [==============================] - 2s 96us/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 25/2000
# 18982/18982 [==============================] - 2s 94us/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 26/2000
# 18982/18982 [==============================] - 2s 97us/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 27/2000
# 18982/18982 [==============================] - 2s 97us/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 28/2000
# 18982/18982 [==============================] - 2s 87us/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 29/2000
# 18982/18982 [==============================] - 2s 102us/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 30/2000
# 18982/18982 [==============================] - 2s 101us/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 31/2000
# 18982/18982 [==============================] - 2s 110us/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 32/2000
# 18982/18982 [==============================] - 2s 109us/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 33/2000
# 18982/18982 [==============================] - 2s 102us/step - loss: 0.0048 - val_loss: 0.0053
# Epoch 34/2000
# 18982/18982 [==============================] - 2s 102us/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 35/2000
# 18982/18982 [==============================] - 2s 97us/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 36/2000
# 18982/18982 [==============================] - 2s 93us/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 37/2000
# 18982/18982 [==============================] - 2s 94us/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 38/2000
# 18982/18982 [==============================] - 2s 88us/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 39/2000
# 18982/18982 [==============================] - 2s 107us/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 40/2000
# 18982/18982 [==============================] - 2s 91us/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 41/2000
# 18982/18982 [==============================] - 2s 103us/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 42/2000
# 18982/18982 [==============================] - 2s 99us/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 43/2000
# 18982/18982 [==============================] - 2s 97us/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 44/2000
# 18982/18982 [==============================] - 2s 92us/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 45/2000
# 18982/18982 [==============================] - 2s 94us/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 46/2000
# 18982/18982 [==============================] - 2s 100us/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 47/2000
# 18982/18982 [==============================] - 2s 108us/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 48/2000
# 18982/18982 [==============================] - 2s 101us/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 49/2000
# 18982/18982 [==============================] - 2s 103us/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 50/2000
# 18982/18982 [==============================] - 2s 105us/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 51/2000
# 18982/18982 [==============================] - 2s 106us/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 52/2000
# 18982/18982 [==============================] - 2s 101us/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 53/2000
# 18982/18982 [==============================] - 2s 102us/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 54/2000
# 18982/18982 [==============================] - 2s 105us/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 55/2000
# 18982/18982 [==============================] - 2s 101us/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 56/2000
# 18982/18982 [==============================] - 2s 97us/step - loss: 0.0045 - val_loss: 0.0051

# %% [markdown]
# Compute the forecast:

# %%
# Compute predictions on train/validation/test sets

y_pred_tr_481 = \
    model_481.predict(X_tr_samples_481.reshape(X_tr_samples_481.shape[0],X_tr_samples_481.shape[1]*X_tr_samples_481.shape[2]),verbose=1)

y_pred_val_481 = \
    model_481.predict(X_val_samples_481.reshape(X_val_samples_481.shape[0],X_val_samples_481.shape[1]*X_val_samples_481.shape[2]),verbose=1)

y_pred_te_481 = \
    model_481.predict(X_te_samples_481.reshape(X_te_samples_481.shape[0],X_te_samples_481.shape[1]*X_te_samples_481.shape[2]),verbose=1)

# Compute a MAE on train/validation/test sets
mae_tr_481 = MAE(y_tr_samples_481[:,0], y_pred_tr_481[:,0])
mae_val_481 = MAE(y_val_samples_481[:,0], y_pred_val_481[:,0])
mae_te_481 = MAE(y_te_samples_481[:,0], y_pred_te_481[:,0])


print('---------')
print('Meter 481')
print('---------')

print('Train set MAE')
print('MAE computed on the train set: ', np.round(mae_tr_481,2))
print('---------')

print('Validation set MAE')
print('MAE computed on the train set: ', np.round(mae_val_481,2))
print('---------')

print('Test set MAE')  
print('MAE computed on the test set: ', np.round(mae_te_481, 2))
print('--------')
# Out:
# 18982/18982 [==============================] - 0s 25us/step
# 2376/2376 [==============================] - 0s 26us/step
# 2376/2376 [==============================] - 0s 30us/step
# ---------
# Meter 481
# ---------
# Train set MAE
# MAE computed on the train set:  0.04
# ---------
# Validation set MAE
# MAE computed on the train set:  0.04
# ---------
# Test set MAE
# MAE computed on the test set:  0.03
# --------

# %% [markdown]
# Plot the forecasts:

# %%
plot_predictions(X_tr_481,X_val_481,X_te_481,y_tr_481,y_val_481,y_te_481,y_pred_tr_481,y_pred_val_481,y_pred_te_481)

# %% [markdown]
# Save the results:

# %%
pred_481 = save_result(481,X_tr_481,X_val_481,X_te_481,y_pred_tr_481[:,0],y_pred_val_481[:,0],y_pred_te_481[:,0])

# %%
pred_481.to_pickle('NeuralNetwork_meter481')

# %% [markdown]
# __Cluster 2__

# %% [markdown]
# Tune a Neural Network model for a meter 60 from the cluster 2.

# %%
meter_60 = df[df['meter_id']==60]
temperature_60 = temperature[temperature.full_date.isin(meter_60.date)]
humidity_60 = humidity[humidity.full_date.isin(meter_60.date)]
meter_60 = meter_60[meter_60.date.isin(temperature_60.full_date)]
meter_60 = meter_60[meter_60.date.isin(humidity_60.full_date)]
meter_60 = meter_60.reset_index()
meter_60['normalized_temp'] = temperature_60.normalized_temp
meter_60['normalized_humid'] = humidity_60.normalized_humidity
meter_60.head(5)
# Out:
#      index  meter_id                date  demand  hours  normalized_demand  \
# 0  1587432        60 2005-01-01 00:00:00  4379.0    0.0           0.078669
# 1  1587433        60 2005-01-01 01:00:00  5598.0    1.0           0.155943
# 2  1587434        60 2005-01-01 02:00:00  5502.0    2.0           0.149857
# 3  1587435        60 2005-01-01 03:00:00  5442.0    3.0           0.146054
# 4  1587436        60 2005-01-01 04:00:00  5562.0    4.0           0.153661
#
#    demand-24h  normalized_demand-24h  normalized_temp  normalized_humid
# 0         NaN                    NaN         0.390571          0.879677
# 1         NaN                    NaN         0.389273          0.869473
# 2         NaN                    NaN         0.378460          0.872874
# 3         NaN                    NaN         0.381055          0.875850
# 4         NaN                    NaN         0.375865          0.877551

# %%
meter_60.dropna(inplace=True)

# %%
X_tr_60,X_val_60,X_te_60,y_tr_60,y_val_60,y_te_60 = \
train_val_test_split(meter_60, 0.2, ['date','normalized_demand-24h','normalized_temp','normalized_humid'])
# Out:
# Train set
# ---------
# Features: (49050, 4) Target: (49050,)
#
# Validation set
# ---------
# Features: (6119, 4) Target: (6119,)
#
# Test set
# --------
# Features: (6144, 4) Target: (6144,)

# %%
X_tr_samples_60, y_tr_samples_60 = split_into_samples(X_tr_60[:,1:],y_tr_60,24,24)
# Out:
# Features samples:  (49050, 24, 3)
# Target samples:  (49050, 24)

# %%
X_val_samples_60, y_val_samples_60 = split_into_samples(X_val_60[:,1:],y_val_60,24,24)
# Out:
# Features samples:  (6119, 24, 3)
# Target samples:  (6119, 24)

# %%
X_te_samples_60, y_te_samples_60 = split_into_samples(X_te_60[:,1:],y_te_60,24,24)
# Out:
# Features samples:  (6144, 24, 3)
# Target samples:  (6144, 24)

# %%
n_config = [5,5],[5,10],[10,5],[15,10],[20,10]

search_result_60 = []
epochs = 2000
batch_size = None

for i in np.arange(len(n_config)):
    print('Tuning neural network for meter 60')
    print('-----------------')
    print('CONFIGURATION SET ' + str(n_config[i]))
    print('-----------------')
    
    model_60 = \
    neural_network_model(n_config[i],epochs,batch_size,X_tr_samples_60,X_val_samples_60,y_tr_samples_60,y_val_samples_60)
    
    # Compute the prediction for this model
    y_pred = \
    model_60.predict(X_te_samples_60.reshape(X_te_samples_60.shape[0], X_te_samples_60.shape[1]*X_te_samples_60.shape[2]), verbose=1)
    
    # Save prediction errors to the dataframe
    result = {'Config': str(n_config[i]), 'MAE_te': (MAE(y_te_samples_60[:,0], y_pred[:,0]))}
    search_result_60.append(result)

search_result_60 = pd.DataFrame(search_result_60)
# Out:
# Tuning neural network for meter 60
# -----------------
# CONFIGURATION SET [5, 5]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 5)                 365
# _________________________________________________________________
# dense_25 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_26 (Dense)             (None, 24)                144
# =================================================================
# Total params: 539
# Trainable params: 539
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 7s 152us/step - loss: 0.0165 - val_loss: 0.0138
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0098 - val_loss: 0.0113
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0076 - val_loss: 0.0107
# Epoch 4/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0074 - val_loss: 0.0113
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0073 - val_loss: 0.0108
# Epoch 6/2000
# 49050/49050 [==============================] - 6s 128us/step - loss: 0.0072 - val_loss: 0.0106
# Epoch 7/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0072 - val_loss: 0.0109
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0071 - val_loss: 0.0100
# Epoch 9/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0068 - val_loss: 0.0105
# Epoch 10/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0067 - val_loss: 0.0102
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0067 - val_loss: 0.0099
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0067 - val_loss: 0.0095
# Epoch 13/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0067 - val_loss: 0.0099
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0067 - val_loss: 0.0099
# Epoch 15/2000
# 49050/49050 [==============================] - 6s 119us/step - loss: 0.0067 - val_loss: 0.0099
# Epoch 16/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 17/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 18/2000
# 49050/49050 [==============================] - 6s 112us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 19/2000
# 49050/49050 [==============================] - 6s 112us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0066 - val_loss: 0.0099
# Epoch 21/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 22/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 23/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 24/2000
# 49050/49050 [==============================] - 6s 112us/step - loss: 0.0066 - val_loss: 0.0098
# Epoch 25/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0066 - val_loss: 0.0099
# Epoch 26/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 27/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 28/2000
# 49050/49050 [==============================] - 6s 112us/step - loss: 0.0066 - val_loss: 0.0102
# Epoch 29/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 30/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0066 - val_loss: 0.0100
# Epoch 31/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 32/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 33/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 34/2000
# 49050/49050 [==============================] - 6s 112us/step - loss: 0.0066 - val_loss: 0.0099
# Epoch 35/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 36/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 37/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 38/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 39/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 40/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 41/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 42/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 43/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 44/2000
# 49050/49050 [==============================] - 6s 116us/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 45/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 46/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 47/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0066 - val_loss: 0.0100
# Epoch 48/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0066 - val_loss: 0.0099
# Epoch 49/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0066 - val_loss: 0.0102
# 6144/6144 [==============================] - 0s 66us/step
# Tuning neural network for meter 60
# -----------------
# CONFIGURATION SET [5, 10]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 5)                 365
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_29 (Dense)             (None, 24)                264
# =================================================================
# Total params: 689
# Trainable params: 689
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0152 - val_loss: 0.0129
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0105 - val_loss: 0.0121
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0102 - val_loss: 0.0120
# Epoch 4/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0100 - val_loss: 0.0120
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0099 - val_loss: 0.0117
# Epoch 6/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0098 - val_loss: 0.0118
# Epoch 7/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0098 - val_loss: 0.0118
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0097 - val_loss: 0.0123
# Epoch 9/2000
# 49050/49050 [==============================] - 5s 92us/step - loss: 0.0097 - val_loss: 0.0124
# Epoch 10/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0097 - val_loss: 0.0113
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0096 - val_loss: 0.0118
# Epoch 13/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0096 - val_loss: 0.0119
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0096 - val_loss: 0.0116
# Epoch 15/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 16/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0096 - val_loss: 0.0121
# Epoch 17/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0096 - val_loss: 0.0117
# Epoch 18/2000
# 49050/49050 [==============================] - 5s 96us/step - loss: 0.0096 - val_loss: 0.0112
# Epoch 19/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0096 - val_loss: 0.0122
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0096 - val_loss: 0.0116
# Epoch 21/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0096 - val_loss: 0.0113
# Epoch 22/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0095 - val_loss: 0.0120
# Epoch 23/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0095 - val_loss: 0.0121
# Epoch 24/2000
# 49050/49050 [==============================] - 5s 96us/step - loss: 0.0094 - val_loss: 0.0117
# Epoch 25/2000
# 49050/49050 [==============================] - 5s 97us/step - loss: 0.0094 - val_loss: 0.0118
# Epoch 26/2000
# 49050/49050 [==============================] - 5s 97us/step - loss: 0.0093 - val_loss: 0.0125
# Epoch 27/2000
# 49050/49050 [==============================] - 5s 98us/step - loss: 0.0093 - val_loss: 0.0113
# Epoch 28/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0093 - val_loss: 0.0120
# 6144/6144 [==============================] - 0s 68us/step
# Tuning neural network for meter 60
# -----------------
# CONFIGURATION SET [10, 5]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 10)                730
# _________________________________________________________________
# dense_31 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_32 (Dense)             (None, 24)                144
# =================================================================
# Total params: 929
# Trainable params: 929
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0183 - val_loss: 0.0139
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0110 - val_loss: 0.0124
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0104 - val_loss: 0.0126
# Epoch 4/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0103 - val_loss: 0.0125
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0103 - val_loss: 0.0129
# Epoch 6/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0103 - val_loss: 0.0124
# Epoch 7/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0102 - val_loss: 0.0119
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0102 - val_loss: 0.0119
# Epoch 9/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0102 - val_loss: 0.0119
# Epoch 10/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0102 - val_loss: 0.0119
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0101 - val_loss: 0.0121
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0101 - val_loss: 0.0122
# Epoch 13/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0101 - val_loss: 0.0118
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 93us/step - loss: 0.0077 - val_loss: 0.0109
# Epoch 15/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0069 - val_loss: 0.0095
# Epoch 16/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0068 - val_loss: 0.0097
# Epoch 17/2000
# 49050/49050 [==============================] - 5s 96us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 18/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0065 - val_loss: 0.0098
# Epoch 19/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 94us/step - loss: 0.0063 - val_loss: 0.0097
# Epoch 21/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0063 - val_loss: 0.0099
# Epoch 22/2000
# 49050/49050 [==============================] - 5s 95us/step - loss: 0.0062 - val_loss: 0.0095
# Epoch 23/2000
# 49050/49050 [==============================] - 8s 166us/step - loss: 0.0062 - val_loss: 0.0101
# Epoch 24/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0062 - val_loss: 0.0095
# Epoch 25/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0061 - val_loss: 0.0096
# Epoch 26/2000
# 49050/49050 [==============================] - 6s 116us/step - loss: 0.0061 - val_loss: 0.0093
# Epoch 27/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0061 - val_loss: 0.0101
# Epoch 28/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0061 - val_loss: 0.0100
# Epoch 29/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0061 - val_loss: 0.0093
# Epoch 30/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0060 - val_loss: 0.0095
# Epoch 31/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0060 - val_loss: 0.0095
# Epoch 32/2000
# 49050/49050 [==============================] - 6s 120us/step - loss: 0.0060 - val_loss: 0.0103
# Epoch 33/2000
# 49050/49050 [==============================] - 6s 119us/step - loss: 0.0060 - val_loss: 0.0091
# Epoch 34/2000
# 49050/49050 [==============================] - 6s 120us/step - loss: 0.0060 - val_loss: 0.0099
# Epoch 35/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0060 - val_loss: 0.0100
# Epoch 36/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0060 - val_loss: 0.0100
# Epoch 37/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0060 - val_loss: 0.0093
# Epoch 38/2000
# 49050/49050 [==============================] - 6s 119us/step - loss: 0.0060 - val_loss: 0.0098
# Epoch 39/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0059 - val_loss: 0.0101
# Epoch 40/2000
# 49050/49050 [==============================] - 6s 119us/step - loss: 0.0059 - val_loss: 0.0097
# Epoch 41/2000
# 49050/49050 [==============================] - 7s 151us/step - loss: 0.0059 - val_loss: 0.0096
# Epoch 42/2000
# 49050/49050 [==============================] - 12s 240us/step - loss: 0.0059 - val_loss: 0.0095
# Epoch 43/2000
# 49050/49050 [==============================] - 7s 149us/step - loss: 0.0059 - val_loss: 0.0096
# 6144/6144 [==============================] - 0s 79us/step
# Tuning neural network for meter 60
# -----------------
# CONFIGURATION SET [15, 10]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 15)                1095
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                160
# _________________________________________________________________
# dense_35 (Dense)             (None, 24)                264
# =================================================================
# Total params: 1,519
# Trainable params: 1,519
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 7s 138us/step - loss: 0.0161 - val_loss: 0.0128
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0087 - val_loss: 0.0108
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0075 - val_loss: 0.0110
# Epoch 4/2000
# 49050/49050 [==============================] - 10s 197us/step - loss: 0.0073 - val_loss: 0.0103ETA: 0s - l
# Epoch 5/2000
# 49050/49050 [==============================] - 13s 258us/step - loss: 0.0069 - val_loss: 0.0099
# Epoch 6/2000
# 49050/49050 [==============================] - 9s 184us/step - loss: 0.0068 - val_loss: 0.0099
# Epoch 7/2000
# 49050/49050 [==============================] - 8s 163us/step - loss: 0.0067 - val_loss: 0.0095
# Epoch 8/2000
# 49050/49050 [==============================] - 8s 163us/step - loss: 0.0067 - val_loss: 0.0100
# Epoch 9/2000
# 49050/49050 [==============================] - 9s 192us/step - loss: 0.0067 - val_loss: 0.0104
# Epoch 10/2000
# 49050/49050 [==============================] - 9s 180us/step - loss: 0.0067 - val_loss: 0.0095
# Epoch 11/2000
# 49050/49050 [==============================] - 7s 140us/step - loss: 0.0067 - val_loss: 0.0097
# Epoch 12/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0067 - val_loss: 0.0098
# Epoch 13/2000
# 49050/49050 [==============================] - 8s 164us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 14/2000
# 49050/49050 [==============================] - 9s 188us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 15/2000
# 49050/49050 [==============================] - 13s 268us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 16/2000
# 49050/49050 [==============================] - 12s 243us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 17/2000
# 49050/49050 [==============================] - 9s 175us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 18/2000
# 49050/49050 [==============================] - 9s 192us/step - loss: 0.0066 - val_loss: 0.0099
# Epoch 19/2000
# 49050/49050 [==============================] - 8s 171us/step - loss: 0.0066 - val_loss: 0.0103
# Epoch 20/2000
# 49050/49050 [==============================] - 8s 172us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 21/2000
# 49050/49050 [==============================] - 8s 166us/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 22/2000
# 49050/49050 [==============================] - 8s 169us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 23/2000
# 49050/49050 [==============================] - 9s 174us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 24/2000
# 49050/49050 [==============================] - 8s 165us/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 25/2000
# 49050/49050 [==============================] - 8s 167us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 26/2000
# 49050/49050 [==============================] - 8s 164us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 27/2000
# 49050/49050 [==============================] - 8s 168us/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 28/2000
# 49050/49050 [==============================] - 8s 160us/step - loss: 0.0066 - val_loss: 0.0098
# Epoch 29/2000
# 49050/49050 [==============================] - 8s 163us/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 30/2000
# 49050/49050 [==============================] - 8s 167us/step - loss: 0.0066 - val_loss: 0.0096
# Epoch 31/2000
# 49050/49050 [==============================] - 8s 161us/step - loss: 0.0066 - val_loss: 0.0098
# Epoch 32/2000
# 49050/49050 [==============================] - 8s 164us/step - loss: 0.0066 - val_loss: 0.0103
# Epoch 33/2000
# 49050/49050 [==============================] - 8s 160us/step - loss: 0.0066 - val_loss: 0.0098
# Epoch 34/2000
# 49050/49050 [==============================] - 9s 177us/step - loss: 0.0066 - val_loss: 0.0095
# 6144/6144 [==============================] - 1s 106us/step
# Tuning neural network for meter 60
# -----------------
# CONFIGURATION SET [20, 10]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 20)                1460
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_38 (Dense)             (None, 24)                264
# =================================================================
# Total params: 1,934
# Trainable params: 1,934
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 10s 202us/step - loss: 0.0157 - val_loss: 0.0124
# Epoch 2/2000
# 49050/49050 [==============================] - 7s 149us/step - loss: 0.0078 - val_loss: 0.0092
# Epoch 3/2000
# 49050/49050 [==============================] - 8s 156us/step - loss: 0.0060 - val_loss: 0.0081
# Epoch 4/2000
# 49050/49050 [==============================] - 8s 154us/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 5/2000
# 49050/49050 [==============================] - 8s 165us/step - loss: 0.0053 - val_loss: 0.0076
# Epoch 6/2000
# 49050/49050 [==============================] - 8s 164us/step - loss: 0.0051 - val_loss: 0.0077
# Epoch 7/2000
# 49050/49050 [==============================] - 8s 162us/step - loss: 0.0050 - val_loss: 0.0078
# Epoch 8/2000
# 49050/49050 [==============================] - 8s 159us/step - loss: 0.0049 - val_loss: 0.0071
# Epoch 9/2000
# 49050/49050 [==============================] - 8s 160us/step - loss: 0.0048 - val_loss: 0.0072
# Epoch 10/2000
# 49050/49050 [==============================] - 8s 154us/step - loss: 0.0047 - val_loss: 0.0070
# Epoch 11/2000
# 49050/49050 [==============================] - 8s 153us/step - loss: 0.0047 - val_loss: 0.0082
# Epoch 12/2000
# 49050/49050 [==============================] - 8s 158us/step - loss: 0.0046 - val_loss: 0.0068
# Epoch 13/2000
# 49050/49050 [==============================] - 8s 159us/step - loss: 0.0045 - val_loss: 0.0070
# Epoch 14/2000
# 49050/49050 [==============================] - 8s 161us/step - loss: 0.0045 - val_loss: 0.0062
# Epoch 15/2000
# 49050/49050 [==============================] - 8s 161us/step - loss: 0.0045 - val_loss: 0.0068
# Epoch 16/2000
# 49050/49050 [==============================] - 8s 163us/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 17/2000
# 49050/49050 [==============================] - 8s 159us/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 18/2000
# 49050/49050 [==============================] - 8s 160us/step - loss: 0.0044 - val_loss: 0.0070
# Epoch 19/2000
# 49050/49050 [==============================] - 8s 166us/step - loss: 0.0044 - val_loss: 0.0062
# Epoch 20/2000
# 49050/49050 [==============================] - 8s 162us/step - loss: 0.0043 - val_loss: 0.0067
# Epoch 21/2000
# 49050/49050 [==============================] - 8s 159us/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 22/2000
# 49050/49050 [==============================] - 8s 162us/step - loss: 0.0043 - val_loss: 0.0064
# Epoch 23/2000
# 49050/49050 [==============================] - 8s 157us/step - loss: 0.0043 - val_loss: 0.0069
# Epoch 24/2000
# 49050/49050 [==============================] - 8s 169us/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 25/2000
# 49050/49050 [==============================] - 8s 158us/step - loss: 0.0043 - val_loss: 0.0073
# Epoch 26/2000
# 49050/49050 [==============================] - 8s 163us/step - loss: 0.0043 - val_loss: 0.0074
# Epoch 27/2000
# 49050/49050 [==============================] - 8s 161us/step - loss: 0.0043 - val_loss: 0.0064
# Epoch 28/2000
# 49050/49050 [==============================] - 8s 163us/step - loss: 0.0043 - val_loss: 0.0068
# Epoch 29/2000
# 49050/49050 [==============================] - 8s 155us/step - loss: 0.0043 - val_loss: 0.0062
# 6144/6144 [==============================] - 1s 122us/step

# %%
search_result_60.sort_values('MAE_te', ascending=True)
# Out:
#      Config    MAE_te
# 4  [20, 10]  0.053767
# 3  [15, 10]  0.055890
# 0    [5, 5]  0.056739
# 2   [10, 5]  0.057641
# 1   [5, 10]  0.065933

# %% [markdown]
# Using a found configuration, compute the forecast for meter 10:

# %%
meter_10 = df[df['meter_id']==10]
temperature_10 = temperature[temperature.full_date.isin(meter_10.date)].reset_index()
humidity_10 = humidity[humidity.full_date.isin(meter_10.date)].reset_index()
meter_10 = meter_10[meter_10.date.isin(temperature_10.full_date)]
meter_10 = meter_10[meter_10.date.isin(humidity_10.full_date)]
meter_10 = meter_10.reset_index()
meter_10['normalized_temp'] = temperature_10.normalized_temp
meter_10['normalized_humid'] = humidity_10.normalized_humidity
meter_10.head(5)
# Out:
#     index  meter_id                date  demand  hours  normalized_demand  \
# 0  483240        10 2005-01-01 00:00:00  2027.0    0.0           0.117804
# 1  483241        10 2005-01-01 01:00:00  3072.0    1.0           0.229211
# 2  483242        10 2005-01-01 02:00:00  2870.0    2.0           0.207676
# 3  483243        10 2005-01-01 03:00:00  2851.0    3.0           0.205650
# 4  483244        10 2005-01-01 04:00:00  2900.0    4.0           0.210874
#
#    demand-24h  normalized_demand-24h  normalized_temp  normalized_humid
# 0         NaN                    NaN         0.390571          0.879677
# 1         NaN                    NaN         0.389273          0.869473
# 2         NaN                    NaN         0.378460          0.872874
# 3         NaN                    NaN         0.381055          0.875850
# 4         NaN                    NaN         0.375865          0.877551

# %%
meter_10.dropna(inplace=True)

# %%
X_tr_10,X_val_10,X_te_10,y_tr_10,y_val_10,y_te_10 = \
train_val_test_split(meter_10, 0.2, ['date','normalized_demand-24h','normalized_temp','normalized_humid'])
# Out:
# Train set
# ---------
# Features: (49050, 4) Target: (49050,)
#
# Validation set
# ---------
# Features: (6119, 4) Target: (6119,)
#
# Test set
# --------
# Features: (6144, 4) Target: (6144,)

# %%
X_tr_samples_10, y_tr_samples_10 = split_into_samples(X_tr_10[:,1:],y_tr_10,24,24)
# Out:
# Features samples:  (49050, 24, 3)
# Target samples:  (49050, 24)

# %%
X_val_samples_10, y_val_samples_10 = split_into_samples(X_val_10[:,1:],y_val_10,24,24)
# Out:
# Features samples:  (6119, 24, 3)
# Target samples:  (6119, 24)

# %%
X_te_samples_10, y_te_samples_10 = split_into_samples(X_te_10[:,1:],y_te_10,24,24)
# Out:
# Features samples:  (6144, 24, 3)
# Target samples:  (6144, 24)

# %%
model_10 = \
    neural_network_model([20,10],2000,None,X_tr_samples_10,X_val_samples_10,y_tr_samples_10,y_val_samples_10)
# Out:
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_39 (Dense)             (None, 20)                1460
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_41 (Dense)             (None, 24)                264
# =================================================================
# Total params: 1,934
# Trainable params: 1,934
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 11s 233us/step - loss: 0.0122 - val_loss: 0.0092
# Epoch 2/2000
# 49050/49050 [==============================] - 8s 158us/step - loss: 0.0065 - val_loss: 0.0075
# Epoch 3/2000
# 49050/49050 [==============================] - 7s 143us/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 4/2000
# 49050/49050 [==============================] - 8s 163us/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 5/2000
# 49050/49050 [==============================] - 7s 143us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 6/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0043 - val_loss: 0.0053
# Epoch 7/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 8/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0041 - val_loss: 0.0058
# Epoch 9/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0041 - val_loss: 0.0052
# Epoch 10/2000
# 49050/49050 [==============================] - 8s 159us/step - loss: 0.0041 - val_loss: 0.0056
# Epoch 11/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0040 - val_loss: 0.0053
# Epoch 12/2000
# 49050/49050 [==============================] - 7s 137us/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 13/2000
# 49050/49050 [==============================] - 7s 139us/step - loss: 0.0040 - val_loss: 0.0053
# Epoch 14/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0040 - val_loss: 0.0052
# Epoch 15/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0040 - val_loss: 0.0050
# Epoch 16/2000
# 49050/49050 [==============================] - 7s 144us/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 17/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 18/2000
# 49050/49050 [==============================] - 7s 133us/step - loss: 0.0039 - val_loss: 0.0052
# Epoch 19/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 20/2000
# 49050/49050 [==============================] - 7s 135us/step - loss: 0.0039 - val_loss: 0.0053
# Epoch 21/2000
# 49050/49050 [==============================] - 7s 136us/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 22/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0039 - val_loss: 0.0053
# Epoch 23/2000
# 49050/49050 [==============================] - 7s 135us/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 24/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0039 - val_loss: 0.0049
# Epoch 25/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 26/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 27/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 28/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 29/2000
# 49050/49050 [==============================] - 6s 120us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 30/2000
# 49050/49050 [==============================] - 6s 122us/step - loss: 0.0038 - val_loss: 0.0052
# Epoch 31/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 32/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 33/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 34/2000
# 49050/49050 [==============================] - 6s 125us/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 35/2000
# 49050/49050 [==============================] - 7s 138us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 36/2000
# 49050/49050 [==============================] - 6s 128us/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 37/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 38/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 39/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 40/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 41/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 42/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 43/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 44/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 45/2000
# 49050/49050 [==============================] - 7s 133us/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 46/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 47/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0037 - val_loss: 0.0050
# Epoch 48/2000
# 49050/49050 [==============================] - 7s 136us/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 49/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 50/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 51/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 52/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0037 - val_loss: 0.0051
# Epoch 53/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 54/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0037 - val_loss: 0.0050
# Epoch 55/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 56/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0037 - val_loss: 0.0047
# Epoch 57/2000
# 49050/49050 [==============================] - 7s 142us/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 58/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0037 - val_loss: 0.0050
# Epoch 59/2000
# 49050/49050 [==============================] - 7s 140us/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 60/2000
# 49050/49050 [==============================] - 6s 122us/step - loss: 0.0037 - val_loss: 0.0047
# Epoch 61/2000
# 49050/49050 [==============================] - 6s 122us/step - loss: 0.0037 - val_loss: 0.0047
# Epoch 62/2000
# 49050/49050 [==============================] - 6s 125us/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 63/2000
# 49050/49050 [==============================] - 6s 125us/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 64/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0037 - val_loss: 0.0052
# Epoch 65/2000
# 49050/49050 [==============================] - 6s 125us/step - loss: 0.0037 - val_loss: 0.0047
# Epoch 66/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 67/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 68/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0036 - val_loss: 0.0047
# Epoch 69/2000
# 49050/49050 [==============================] - 7s 136us/step - loss: 0.0036 - val_loss: 0.0047
# Epoch 70/2000
# 49050/49050 [==============================] - 7s 137us/step - loss: 0.0036 - val_loss: 0.0049

# %%
# Compute predictions on train/validation/test sets

y_pred_tr_10 = \
    model_10.predict(X_tr_samples_10.reshape(X_tr_samples_10.shape[0],X_tr_samples_10.shape[1]*X_tr_samples_10.shape[2]),verbose=1)

y_pred_val_10 = \
    model_10.predict(X_val_samples_10.reshape(X_val_samples_10.shape[0],X_val_samples_10.shape[1]*X_val_samples_10.shape[2]),verbose=1)

y_pred_te_10 = \
    model_10.predict(X_te_samples_10.reshape(X_te_samples_10.shape[0],X_te_samples_10.shape[1]*X_te_samples_10.shape[2]),verbose=1)

# Compute a MAE on train/validation/test sets
mae_tr_10 = MAE(y_tr_samples_10[:,0], y_pred_tr_10[:,0])
mae_val_10 = MAE(y_val_samples_10[:,0], y_pred_val_10[:,0])
mae_te_10 = MAE(y_te_samples_10[:,0], y_pred_te_10[:,0])


print('---------')
print('Meter 10')
print('---------')

print('Train set MAE')
print('MAE computed on the train set: ', np.round(mae_tr_10,2))
print('---------')

print('Validation set MAE')
print('MAE computed on the train set: ', np.round(mae_val_10,2))
print('---------')

print('Test set MAE')  
print('MAE computed on the test set: ', np.round(mae_te_10, 2))
print('--------')
# Out:
# 49050/49050 [==============================] - 2s 39us/step
# 6119/6119 [==============================] - 0s 30us/step
# 6144/6144 [==============================] - 0s 30us/step
# ---------
# Meter 10
# ---------
# Train set MAE
# MAE computed on the train set:  0.03
# ---------
# Validation set MAE
# MAE computed on the train set:  0.04
# ---------
# Test set MAE
# MAE computed on the test set:  0.04
# --------

# %%
plot_predictions(X_tr_10,X_val_10,X_te_10,y_tr_10,y_val_10,y_te_10,y_pred_tr_10,y_pred_val_10,y_pred_te_10)

# %%
pred_10 = save_result(10,X_tr_10,X_val_10,X_te_10,y_pred_tr_10[:,0],y_pred_val_10[:,0],y_pred_te_10[:,0])

# %%
pred_10.to_pickle('NeuralNetwork_meter10')

# %% [markdown]
# __Cluster 3__

# %% [markdown]
# Tune a Neural Network model for a meter 412 from the cluster 3.

# %%
meter_412 = df[df['meter_id']==412]
temperature_412 = temperature[temperature.full_date.isin(meter_412.date)]
humidity_412 = humidity[humidity.full_date.isin(meter_412.date)]
meter_412 = meter_412[meter_412.date.isin(temperature_412.full_date)]
meter_412 = meter_412[meter_412.date.isin(humidity_412.full_date)]
meter_412 = meter_412.reset_index()
meter_412['normalized_temp'] = temperature_412.normalized_temp
meter_412['normalized_humid'] = humidity_412.normalized_humidity
meter_412.head()
# Out:
#      index  meter_id                date  demand  hours  normalized_demand  \
# 0  7979568       412 2005-01-01 00:00:00   714.5    0.0           0.324478
# 1  7979569       412 2005-01-01 01:00:00     8.0    1.0           0.003633
# 2  7979570       412 2005-01-01 02:00:00     8.0    2.0           0.003633
# 3  7979571       412 2005-01-01 03:00:00     8.0    3.0           0.003633
# 4  7979572       412 2005-01-01 04:00:00     8.0    4.0           0.003633
#
#    demand-24h  normalized_demand-24h  normalized_temp  normalized_humid
# 0         NaN                    NaN         0.390571          0.879677
# 1         NaN                    NaN         0.389273          0.869473
# 2         NaN                    NaN         0.378460          0.872874
# 3         NaN                    NaN         0.381055          0.875850
# 4         NaN                    NaN         0.375865          0.877551

# %%
meter_412.dropna(inplace=True)

# %%
X_tr_412,X_val_412,X_te_412,y_tr_412,y_val_412,y_te_412 = \
train_val_test_split(meter_412, 0.2, ['date','normalized_demand-24h','normalized_temp','normalized_humid'])
# Out:
# Train set
# ---------
# Features: (49050, 4) Target: (49050,)
#
# Validation set
# ---------
# Features: (6119, 4) Target: (6119,)
#
# Test set
# --------
# Features: (6144, 4) Target: (6144,)

# %%
X_tr_samples_412, y_tr_samples_412 = split_into_samples(X_tr_412[:,1:],y_tr_412,24,24)
# Out:
# Features samples:  (49050, 24, 3)
# Target samples:  (49050, 24)

# %%
X_val_samples_412, y_val_samples_412 = split_into_samples(X_val_412[:,1:],y_val_412,24,24)
# Out:
# Features samples:  (6119, 24, 3)
# Target samples:  (6119, 24)

# %%
X_te_samples_412, y_te_samples_412 = split_into_samples(X_te_412[:,1:],y_te_412,24,24)
# Out:
# Features samples:  (6144, 24, 3)
# Target samples:  (6144, 24)

# %%
n_config = [5,5],[5,10],[10,5],[15,10],[20,10]

search_result_412 = []
epochs = 2000
batch_size = None

for i in np.arange(len(n_config)):
    print('Tuning neural network for meter 412')
    print('-----------------')
    print('CONFIGURATION SET ' + str(n_config[i]))
    print('-----------------')
    
    model_412 = \
    neural_network_model(n_config[i],epochs,batch_size,X_tr_samples_412,X_val_samples_412,y_tr_samples_412,y_val_samples_412)
    
    # Compute the prediction for this model
    y_pred = \
    model_412.predict(X_te_samples_412.reshape(X_te_samples_412.shape[0], X_te_samples_412.shape[1]*X_te_samples_412.shape[2]), verbose=1)
    
    # Save prediction errors to the dataframe
    result = {'Config': str(n_config[i]), 'MAE_te': (MAE(y_te_samples_412[:,0], y_pred[:,0]))}
    search_result_412.append(result)

search_result_412 = pd.DataFrame(search_result_412)
# Out:
# Tuning neural network for meter 412
# -----------------
# CONFIGURATION SET [5, 5]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 5)                 365
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_44 (Dense)             (None, 24)                144
# =================================================================
# Total params: 539
# Trainable params: 539
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 9s 189us/step - loss: 0.0104 - val_loss: 0.0056
# Epoch 2/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0045 - val_loss: 0.0055
# Epoch 3/2000
# 49050/49050 [==============================] - 7s 149us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 4/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 6/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 7/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 9/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0043 - val_loss: 0.0051
# Epoch 10/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0036 - val_loss: 0.0045
# Epoch 13/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 15/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 16/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 17/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 18/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 19/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 21/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 22/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 23/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 24/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 25/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 26/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 27/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 28/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 29/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 30/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 31/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 32/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 33/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 34/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 35/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 36/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 37/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 38/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 39/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 40/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 41/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 42/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 43/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 44/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 45/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 46/2000
# 49050/49050 [==============================] - 7s 149us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 47/2000
# 49050/49050 [==============================] - 6s 127us/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 48/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0035 - val_loss: 0.0043
# 6144/6144 [==============================] - 1s 96us/step
# Tuning neural network for meter 412
# -----------------
# CONFIGURATION SET [5, 10]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 5)                 365
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_47 (Dense)             (None, 24)                264
# =================================================================
# Total params: 689
# Trainable params: 689
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 7s 141us/step - loss: 0.0089 - val_loss: 0.0054
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0038 - val_loss: 0.0044
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 103us/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 4/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 6/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 7/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 9/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 10/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 13/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 103us/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 15/2000
# 49050/49050 [==============================] - 5s 103us/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 16/2000
# 49050/49050 [==============================] - 5s 103us/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 17/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 18/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 19/2000
# 49050/49050 [==============================] - 6s 121us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 21/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 22/2000
# 49050/49050 [==============================] - 6s 121us/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 23/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 24/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 25/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 26/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 27/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 28/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 29/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 30/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 31/2000
# 49050/49050 [==============================] - 5s 104us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 32/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 33/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 34/2000
# 49050/49050 [==============================] - 6s 120us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 35/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 36/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 37/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 38/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 39/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 40/2000
# 49050/49050 [==============================] - 6s 119us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 41/2000
# 49050/49050 [==============================] - 6s 112us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 42/2000
# 49050/49050 [==============================] - 7s 136us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 43/2000
# 49050/49050 [==============================] - 6s 120us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 44/2000
# 49050/49050 [==============================] - 6s 116us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 45/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 46/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 47/2000
# 49050/49050 [==============================] - 9s 187us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 48/2000
# 49050/49050 [==============================] - 7s 147us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 49/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 50/2000
# 49050/49050 [==============================] - 6s 116us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 51/2000
# 49050/49050 [==============================] - 6s 116us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 52/2000
# 49050/49050 [==============================] - 6s 120us/step - loss: 0.0021 - val_loss: 0.0027
# 6144/6144 [==============================] - 1s 105us/step
# Tuning neural network for meter 412
# -----------------
# CONFIGURATION SET [10, 5]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_48 (Dense)             (None, 10)                730
# _________________________________________________________________
# dense_49 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_50 (Dense)             (None, 24)                144
# =================================================================
# Total params: 929
# Trainable params: 929
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 7s 146us/step - loss: 0.0096 - val_loss: 0.0056
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0045 - val_loss: 0.0055
# Epoch 4/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 6/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 7/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 9/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 10/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 13/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 14/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 15/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 16/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 17/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 18/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 19/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 21/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 22/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 23/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 24/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 25/2000
# 49050/49050 [==============================] - 6s 115us/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 26/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0044 - val_loss: 0.0054
# Epoch 27/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0044 - val_loss: 0.0054
# 6144/6144 [==============================] - 1s 159us/step
# Tuning neural network for meter 412
# -----------------
# CONFIGURATION SET [15, 10]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_51 (Dense)             (None, 15)                1095
# _________________________________________________________________
# dense_52 (Dense)             (None, 10)                160
# _________________________________________________________________
# dense_53 (Dense)             (None, 24)                264
# =================================================================
# Total params: 1,519
# Trainable params: 1,519
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 7s 150us/step - loss: 0.0077 - val_loss: 0.0048
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 3/2000
# 49050/49050 [==============================] - 5s 105us/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 4/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 6/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 7/2000
# 49050/49050 [==============================] - 5s 106us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 9/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 10/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 11/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 13/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 15/2000
# 49050/49050 [==============================] - 6s 118us/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 16/2000
# 49050/49050 [==============================] - 6s 132us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 17/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 18/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 19/2000
# 49050/49050 [==============================] - 6s 116us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 21/2000
# 49050/49050 [==============================] - 6s 119us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 22/2000
# 49050/49050 [==============================] - 7s 138us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 23/2000
# 49050/49050 [==============================] - 9s 186us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 24/2000
# 49050/49050 [==============================] - 8s 165us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 25/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 26/2000
# 49050/49050 [==============================] - 6s 121us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 27/2000
# 49050/49050 [==============================] - 6s 122us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 28/2000
# 49050/49050 [==============================] - 7s 135us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 29/2000
# 49050/49050 [==============================] - 6s 126us/step - loss: 0.0021 - val_loss: 0.0030
# 6144/6144 [==============================] - 1s 171us/step
# Tuning neural network for meter 412
# -----------------
# CONFIGURATION SET [20, 10]
# -----------------
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_54 (Dense)             (None, 20)                1460
# _________________________________________________________________
# dense_55 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_56 (Dense)             (None, 24)                264
# =================================================================
# Total params: 1,934
# Trainable params: 1,934
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49050 samples, validate on 6119 samples
# Epoch 1/2000
# 49050/49050 [==============================] - 7s 147us/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 2/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 3/2000
# 49050/49050 [==============================] - 6s 128us/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 4/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 5/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 6/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 7/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 8/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 9/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 10/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 11/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 12/2000
# 49050/49050 [==============================] - 5s 107us/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 13/2000
# 49050/49050 [==============================] - 6s 113us/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 14/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 15/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 16/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 17/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 18/2000
# 49050/49050 [==============================] - 6s 117us/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 19/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 20/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 21/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 22/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 23/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 24/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 25/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 26/2000
# 49050/49050 [==============================] - 6s 127us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 27/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 28/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 29/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 30/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 31/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 32/2000
# 49050/49050 [==============================] - 5s 108us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 33/2000
# 49050/49050 [==============================] - 5s 109us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 34/2000
# 49050/49050 [==============================] - 6s 120us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 35/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 36/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 37/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 38/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 39/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 40/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 41/2000
# 49050/49050 [==============================] - 5s 112us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 42/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 43/2000
# 49050/49050 [==============================] - 5s 111us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 44/2000
# 49050/49050 [==============================] - 5s 110us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 45/2000
# 49050/49050 [==============================] - 6s 114us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 46/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 47/2000
# 49050/49050 [==============================] - 6s 116us/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 48/2000
# 49050/49050 [==============================] - 6s 121us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 49/2000
# 49050/49050 [==============================] - 9s 190us/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 50/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 51/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 52/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 53/2000
# 49050/49050 [==============================] - 6s 124us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 54/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 55/2000
# 49050/49050 [==============================] - 6s 122us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 56/2000
# 49050/49050 [==============================] - 6s 128us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 57/2000
# 49050/49050 [==============================] - 7s 146us/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 58/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 59/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 60/2000
# 49050/49050 [==============================] - 6s 125us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 61/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 62/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 63/2000
# 49050/49050 [==============================] - 6s 123us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 64/2000
# 49050/49050 [==============================] - 9s 177us/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 65/2000
# 49050/49050 [==============================] - 6s 131us/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 66/2000
# 49050/49050 [==============================] - 7s 141us/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 67/2000
# 49050/49050 [==============================] - 7s 151us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 68/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 69/2000
# 49050/49050 [==============================] - 6s 130us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 70/2000
# 49050/49050 [==============================] - 6s 128us/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 71/2000
# 49050/49050 [==============================] - 6s 129us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 72/2000
# 49050/49050 [==============================] - 7s 134us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 73/2000
# 49050/49050 [==============================] - 8s 173us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 74/2000
# 49050/49050 [==============================] - 8s 153us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 75/2000
# 49050/49050 [==============================] - 7s 136us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 76/2000
# 49050/49050 [==============================] - 8s 164us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 77/2000
# 49050/49050 [==============================] - 10s 205us/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 78/2000
# 49050/49050 [==============================] - 9s 189us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 79/2000
# 49050/49050 [==============================] - 9s 191us/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 80/2000
# 49050/49050 [==============================] - 8s 162us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 81/2000
# 49050/49050 [==============================] - 9s 178us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 82/2000
# 49050/49050 [==============================] - 7s 146us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 83/2000
# 49050/49050 [==============================] - 7s 142us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 84/2000
# 49050/49050 [==============================] - 7s 152us/step - loss: 0.0015 - val_loss: 0.0023
# 6144/6144 [==============================] - 1s 115us/step

# %%
search_result_412.sort_values(by='MAE_te', ascending=True)
# Out:
#      Config    MAE_te
# 4  [20, 10]  0.020668
# 3  [15, 10]  0.024540
# 0    [5, 5]  0.026994
# 1   [5, 10]  0.027995
# 2   [10, 5]  0.036553

# %% [markdown]
# Using a found configuration, compute the forecast for meter 453:

# %%
meter_453 = df[df['meter_id']==453]
temperature_453 = temperature[temperature.full_date.isin(meter_453.date)].reset_index()
humidity_453 = humidity[humidity.full_date.isin(meter_453.date)].reset_index()
meter_453 = meter_453[meter_453.date.isin(temperature_453.full_date)]
meter_453 = meter_453[meter_453.date.isin(humidity_453.full_date)]
meter_453 = meter_453.reset_index()
meter_453['normalized_temp'] = temperature_453.normalized_temp
meter_453['normalized_humid'] = humidity_453.normalized_humidity
meter_453.head(5)
# Out:
#      index  meter_id                date  demand  hours  normalized_demand  \
# 0  8980008       453 2005-06-01 00:00:00  1898.5    0.0           0.392983
# 1  8980009       453 2005-06-01 01:00:00     0.0    1.0           0.000000
# 2  8980010       453 2005-06-01 02:00:00     0.0    2.0           0.000000
# 3  8980011       453 2005-06-01 03:00:00     0.0    3.0           0.000000
# 4  8980012       453 2005-06-01 04:00:00     0.0    4.0           0.000000
#
#    demand-24h  normalized_demand-24h  normalized_temp  normalized_humid
# 0         NaN                    NaN         0.608131          0.737245
# 1         NaN                    NaN         0.602941          0.736395
# 2         NaN                    NaN         0.595156          0.760204
# 3         NaN                    NaN         0.586505          0.781037
# 4         NaN                    NaN         0.581315          0.802721

# %%
meter_453.dropna(inplace=True)

# %%
X_tr_453,X_val_453,X_te_453,y_tr_453,y_val_453,y_te_453 = \
train_val_test_split(meter_453, 0.2, ['date','normalized_demand-24h','normalized_temp','normalized_humid'])
# Out:
# Train set
# ---------
# Features: (46147, 4) Target: (46147,)
#
# Validation set
# ---------
# Features: (5759, 4) Target: (5759,)
#
# Test set
# --------
# Features: (5784, 4) Target: (5784,)

# %%
X_tr_samples_453, y_tr_samples_453 = split_into_samples(X_tr_453[:,1:],y_tr_453,24,24)
# Out:
# Features samples:  (46147, 24, 3)
# Target samples:  (46147, 24)

# %%
X_val_samples_453, y_val_samples_453 = split_into_samples(X_val_453[:,1:],y_val_453,24,24)
# Out:
# Features samples:  (5759, 24, 3)
# Target samples:  (5759, 24)

# %%
X_te_samples_453, y_te_samples_453 = split_into_samples(X_te_453[:,1:],y_te_453,24,24)
# Out:
# Features samples:  (5784, 24, 3)
# Target samples:  (5784, 24)

# %%
model_453 = \
    neural_network_model([20,10],2000,None,X_tr_samples_453,X_val_samples_453,y_tr_samples_453,y_val_samples_453)
# Out:
# Network configuration
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_57 (Dense)             (None, 20)                1460
# _________________________________________________________________
# dense_58 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_59 (Dense)             (None, 24)                264
# =================================================================
# Total params: 1,934
# Trainable params: 1,934
# Non-trainable params: 0
# _________________________________________________________________
# Train on 46147 samples, validate on 5759 samples
# Epoch 1/2000
# 46147/46147 [==============================] - 14s 302us/step - loss: 0.0070 - val_loss: 0.0042
# Epoch 2/2000
# 46147/46147 [==============================] - 7s 160us/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 3/2000
# 46147/46147 [==============================] - 6s 124us/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 4/2000
# 46147/46147 [==============================] - 10s 225us/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 5/2000
# 46147/46147 [==============================] - 7s 146us/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 6/2000
# 46147/46147 [==============================] - 7s 144us/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 7/2000
# 46147/46147 [==============================] - 6s 138us/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 8/2000
# 46147/46147 [==============================] - 6s 139us/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 9/2000
# 46147/46147 [==============================] - 7s 146us/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 10/2000
# 46147/46147 [==============================] - 6s 141us/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 11/2000
# 46147/46147 [==============================] - 6s 140us/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 12/2000
# 46147/46147 [==============================] - 7s 146us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 13/2000
# 46147/46147 [==============================] - 7s 147us/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 14/2000
# 46147/46147 [==============================] - 7s 145us/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 15/2000
# 46147/46147 [==============================] - 6s 140us/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 16/2000
# 46147/46147 [==============================] - 7s 142us/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 17/2000
# 46147/46147 [==============================] - 7s 141us/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 18/2000
# 46147/46147 [==============================] - 7s 148us/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 19/2000
# 46147/46147 [==============================] - 6s 141us/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 20/2000
# 46147/46147 [==============================] - 7s 147us/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 21/2000
# 46147/46147 [==============================] - 6s 138us/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 22/2000
# 46147/46147 [==============================] - 6s 133us/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 23/2000
# 46147/46147 [==============================] - 8s 163us/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 24/2000
# 46147/46147 [==============================] - 12s 252us/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 25/2000
# 46147/46147 [==============================] - 8s 167us/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 26/2000
# 46147/46147 [==============================] - 9s 200us/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 27/2000
# 46147/46147 [==============================] - 7s 153us/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 28/2000
# 46147/46147 [==============================] - 6s 134us/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 29/2000
# 46147/46147 [==============================] - 6s 139us/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 30/2000
# 46147/46147 [==============================] - 6s 140us/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 31/2000
# 46147/46147 [==============================] - 6s 141us/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 32/2000
# 46147/46147 [==============================] - 7s 151us/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 33/2000
# 46147/46147 [==============================] - 11s 234us/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 34/2000
# 46147/46147 [==============================] - 9s 199us/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 35/2000
# 46147/46147 [==============================] - 9s 198us/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 36/2000
# 46147/46147 [==============================] - 7s 159us/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 37/2000
# 46147/46147 [==============================] - 6s 134us/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 38/2000
# 46147/46147 [==============================] - 7s 142us/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 39/2000
# 46147/46147 [==============================] - 6s 136us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 40/2000
# 46147/46147 [==============================] - 6s 137us/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 41/2000
# 46147/46147 [==============================] - 9s 191us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 42/2000
# 46147/46147 [==============================] - 11s 231us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 43/2000
# 46147/46147 [==============================] - 7s 155us/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 44/2000
# 46147/46147 [==============================] - 10s 222us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 45/2000
# 46147/46147 [==============================] - 7s 145us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 46/2000
# 46147/46147 [==============================] - 7s 152us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 47/2000
# 46147/46147 [==============================] - 7s 145us/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 48/2000
# 46147/46147 [==============================] - 7s 144us/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 49/2000
# 46147/46147 [==============================] - 7s 145us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 50/2000
# 46147/46147 [==============================] - 7s 148us/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 51/2000
# 46147/46147 [==============================] - 7s 148us/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 52/2000
# 46147/46147 [==============================] - 7s 147us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 53/2000
# 46147/46147 [==============================] - 7s 150us/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 54/2000
# 46147/46147 [==============================] - 7s 151us/step - loss: 0.0017 - val_loss: 0.0022

# %%
# Compute predictions on train/validation/test sets

y_pred_tr_453 = \
    model_453.predict(X_tr_samples_453.reshape(X_tr_samples_453.shape[0],X_tr_samples_453.shape[1]*X_tr_samples_453.shape[2]),verbose=1)

y_pred_val_453 = \
    model_453.predict(X_val_samples_453.reshape(X_val_samples_453.shape[0],X_val_samples_453.shape[1]*X_val_samples_453.shape[2]),verbose=1)

y_pred_te_453 = \
    model_453.predict(X_te_samples_453.reshape(X_te_samples_453.shape[0],X_te_samples_453.shape[1]*X_te_samples_453.shape[2]),verbose=1)

# Compute a MAE on train/validation/test sets
mae_tr_453 = MAE(y_tr_samples_453[:,0], y_pred_tr_453[:,0])
mae_val_453 = MAE(y_val_samples_453[:,0], y_pred_val_453[:,0])
mae_te_453 = MAE(y_te_samples_453[:,0], y_pred_te_453[:,0])


print('---------')
print('Meter 10')
print('---------')

print('Train set MAE')
print('MAE computed on the train set: ', np.round(mae_tr_453,2))
print('---------')

print('Validation set MAE')
print('MAE computed on the train set: ', np.round(mae_val_453,2))
print('---------')

print('Test set MAE')  
print('MAE computed on the test set: ', np.round(mae_te_453, 2))
print('--------')
# Out:
# 46147/46147 [==============================] - 2s 54us/step
# 5759/5759 [==============================] - 0s 40us/step
# 5784/5784 [==============================] - 0s 41us/step
# ---------
# Meter 10
# ---------
# Train set MAE
# MAE computed on the train set:  0.02
# ---------
# Validation set MAE
# MAE computed on the train set:  0.03
# ---------
# Test set MAE
# MAE computed on the test set:  0.05
# --------

# %%
plot_predictions(X_tr_453,X_val_453,X_te_453,y_tr_453,y_val_453,y_te_453,y_pred_tr_453,y_pred_val_453,y_pred_te_453)

# %%
pred_453 = save_result(453,X_tr_453,X_val_453,X_te_453,y_pred_tr_453[:,0],y_pred_val_453[:,0],y_pred_te_453[:,0])

# %%
pred_453.to_pickle('NeuralNetwork_meter453')
